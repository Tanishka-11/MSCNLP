# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import FreqDist
import pandas as pd
import numpy as np
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
f = open("/content/Dataset.txt")
sample = f.read()

# %%
sample_tokens = nltk.word_tokenize(sample)
print('\n Sample Tokens:',sample_tokens)
print('\n Type of Sample Tokens:',type(sample_tokens))
print('\n Length of Sample Tokens:',len(sample_tokens))
# Out:
#  Sample Tokens: ['speakers', ':', 'the', 'sender', 'of', 'the', 'message', '(', 'string', 'format', '.', 'russia', ',', 'turkey', ',', 'england', '...', ')', 'receivers', ':', 'the', 'receiver', 'of', 'the', 'message', '(', 'string', 'format', '.', 'russia', ',', 'turkey', ',', 'england', '...', ')', 'messages', ':', 'the', 'raw', 'message', 'string', '(', 'string', 'format', '.', 'ranges', 'in', 'length', 'from', 'one', 'word', 'to', 'paragraphs', 'in', 'length', ')', 'sender_labels', ':', 'indicates', 'if', 'the', 'sender', 'of', 'the', 'message', 'selected', 'that', 'the', 'message', 'is', 'truthful', ',', 'true', ',', 'or', 'deceptive', ',', 'false', '.', 'This', 'is', 'used', 'for', 'our', 'ACTUAL_LIE', 'calculation', '(', 'true/false', 'which', 'can', 'be', 'bool', 'or', 'string', 'format', ')', 'receiver_labels', ':', 'indicates', 'if', 'the', 'receiver', 'of', 'the', 'message', 'selected', 'that', 'the', 'message', 'is', 'perceived', 'as', 'truthful', ',', 'true', ',', 'or', 'deceptive', ',', 'false', '.', 'In', '<', '10', '%', 'of', 'the', 'cases', ',', 'no', 'annotation', 'was', 'received', '.', 'This', 'is', 'used', 'for', 'our', 'SUSPECTED_LIE', 'calculation', '(', 'string', 'format', '.', 'true/false/', "''", 'NOANNOTATION', "''", ')', 'game_score', ':', 'the', 'current', 'game', 'score', '--', '-supply', 'centers', '--', '-of', 'the', 'sender', '(', 'string', 'format', 'that', 'ranges', 'can', 'range', 'from', '0', 'to', '18', ')', 'score_delta', ':', 'the', 'current', 'game', 'score', '--', '-supply', 'centers', '--', '-of', 'the', 'sender', 'minus', 'the', 'game', 'score', 'of', 'the', 'recipient', '(', 'string', 'format', 'that', 'ranges', 'from', '-18', 'to', '18', ')', 'absolute_message_index', ':', 'the', 'index', 'the', 'message', 'is', 'in', 'the', 'entire', 'game', ',', 'across', 'all', 'dialogs', '(', 'int', 'format', ')', 'relative_message_index', ':', 'the', 'index', 'of', 'the', 'message', 'in', 'the', 'current', 'dialog', '(', 'int', 'format', ')', 'seasons', ':', 'the', 'season', 'in', 'Diplomacy', ',', 'associated', 'with', 'the', 'year', '(', 'string', 'format', '.', 'Spring', ',', 'Fall', ',', 'Winter', ')', 'years', ':', 'the', 'year', 'in', 'Diplomacy', ',', 'associated', 'with', 'the', 'season', '(', 'string', 'format', '.', '1901', 'through', '1918', ')', 'game_id', ':', 'which', 'of', 'the', '12', 'games', 'the', 'dialog', 'comes', 'from', '(', 'int', 'format', 'ranging', 'from', '1', 'to', '12', ')']
#
#  Type of Sample Tokens: <class 'list'>
#
#  Length of Sample Tokens: 300

# %%
sample_freq =FreqDist(sample_tokens)
tokens=[]
sf=[]
for i in sample_freq:
    pass # Replace with your code

# %%
tokens.append(i)
sf.append(sample_freq[i])

# %%
df = pd.DataFrame({'Tokens':tokens,'Frequency':sf})
print('\n',df)
# Out:
#    Tokens  Frequency
# 0      1          1

# %%
print('\n Bigrams:',list(nltk.bigrams(sample_tokens)))
print('\n Trigrams:',list(nltk.trigrams(sample_tokens)))
print('\n N- grams(4):',list(nltk.ngrams(sample_tokens,4)))
# Out:
#  Bigrams: [('speakers', ':'), (':', 'the'), ('the', 'sender'), ('sender', 'of'), ('of', 'the'), ('the', 'message'), ('message', '('), ('(', 'string'), ('string', 'format'), ('format', '.'), ('.', 'russia'), ('russia', ','), (',', 'turkey'), ('turkey', ','), (',', 'england'), ('england', '...'), ('...', ')'), (')', 'receivers'), ('receivers', ':'), (':', 'the'), ('the', 'receiver'), ('receiver', 'of'), ('of', 'the'), ('the', 'message'), ('message', '('), ('(', 'string'), ('string', 'format'), ('format', '.'), ('.', 'russia'), ('russia', ','), (',', 'turkey'), ('turkey', ','), (',', 'england'), ('england', '...'), ('...', ')'), (')', 'messages'), ('messages', ':'), (':', 'the'), ('the', 'raw'), ('raw', 'message'), ('message', 'string'), ('string', '('), ('(', 'string'), ('string', 'format'), ('format', '.'), ('.', 'ranges'), ('ranges', 'in'), ('in', 'length'), ('length', 'from'), ('from', 'one'), ('one', 'word'), ('word', 'to'), ('to', 'paragraphs'), ('paragraphs', 'in'), ('in', 'length'), ('length', ')'), (')', 'sender_labels'), ('sender_labels', ':'), (':', 'indicates'), ('indicates', 'if'), ('if', 'the'), ('the', 'sender'), ('sender', 'of'), ('of', 'the'), ('the', 'message'), ('message', 'selected'), ('selected', 'that'), ('that', 'the'), ('the', 'message'), ('message', 'is'), ('is', 'truthful'), ('truthful', ','), (',', 'true'), ('true', ','), (',', 'or'), ('or', 'deceptive'), ('deceptive', ','), (',', 'false'), ('false', '.'), ('.', 'This'), ('This', 'is'), ('is', 'used'), ('used', 'for'), ('for', 'our'), ('our', 'ACTUAL_LIE'), ('ACTUAL_LIE', 'calculation'), ('calculation', '('), ('(', 'true/false'), ('true/false', 'which'), ('which', 'can'), ('can', 'be'), ('be', 'bool'), ('bool', 'or'), ('or', 'string'), ('string', 'format'), ('format', ')'), (')', 'receiver_labels'), ('receiver_labels', ':'), (':', 'indicates'), ('indicates', 'if'), ('if', 'the'), ('the', 'receiver'), ('receiver', 'of'), ('of', 'the'), ('the', 'message'), ('message', 'selected'), ('selected', 'that'), ('that', 'the'), ('the', 'message'), ('message', 'is'), ('is', 'perceived'), ('perceived', 'as'), ('as', 'truthful'), ('truthful', ','), (',', 'true'), ('true', ','), (',', 'or'), ('or', 'deceptive'), ('deceptive', ','), (',', 'false'), ('false', '.'), ('.', 'In'), ('In', '<'), ('<', '10'), ('10', '%'), ('%', 'of'), ('of', 'the'), ('the', 'cases'), ('cases', ','), (',', 'no'), ('no', 'annotation'), ('annotation', 'was'), ('was', 'received'), ('received', '.'), ('.', 'This'), ('This', 'is'), ('is', 'used'), ('used', 'for'), ('for', 'our'), ('our', 'SUSPECTED_LIE'), ('SUSPECTED_LIE', 'calculation'), ('calculation', '('), ('(', 'string'), ('string', 'format'), ('format', '.'), ('.', 'true/false/'), ('true/false/', "''"), ("''", 'NOANNOTATION'), ('NOANNOTATION', "''"), ("''", ')'), (')', 'game_score'), ('game_score', ':'), (':', 'the'), ('the', 'current'), ('current', 'game'), ('game', 'score'), ('score', '--'), ('--', '-supply'), ('-supply', 'centers'), ('centers', '--'), ('--', '-of'), ('-of', 'the'), ('the', 'sender'), ('sender', '('), ('(', 'string'), ('string', 'format'), ('format', 'that'), ('that', 'ranges'), ('ranges', 'can'), ('can', 'range'), ('range', 'from'), ('from', '0'), ('0', 'to'), ('to', '18'), ('18', ')'), (')', 'score_delta'), ('score_delta', ':'), (':', 'the'), ('the', 'current'), ('current', 'game'), ('game', 'score'), ('score', '--'), ('--', '-supply'), ('-supply', 'centers'), ('centers', '--'), ('--', '-of'), ('-of', 'the'), ('the', 'sender'), ('sender', 'minus'), ('minus', 'the'), ('the', 'game'), ('game', 'score'), ('score', 'of'), ('of', 'the'), ('the', 'recipient'), ('recipient', '('), ('(', 'string'), ('string', 'format'), ('format', 'that'), ('that', 'ranges'), ('ranges', 'from'), ('from', '-18'), ('-18', 'to'), ('to', '18'), ('18', ')'), (')', 'absolute_message_index'), ('absolute_message_index', ':'), (':', 'the'), ('the', 'index'), ('index', 'the'), ('the', 'message'), ('message', 'is'), ('is', 'in'), ('in', 'the'), ('the', 'ent ...
#
#  Trigrams: [('speakers', ':', 'the'), (':', 'the', 'sender'), ('the', 'sender', 'of'), ('sender', 'of', 'the'), ('of', 'the', 'message'), ('the', 'message', '('), ('message', '(', 'string'), ('(', 'string', 'format'), ('string', 'format', '.'), ('format', '.', 'russia'), ('.', 'russia', ','), ('russia', ',', 'turkey'), (',', 'turkey', ','), ('turkey', ',', 'england'), (',', 'england', '...'), ('england', '...', ')'), ('...', ')', 'receivers'), (')', 'receivers', ':'), ('receivers', ':', 'the'), (':', 'the', 'receiver'), ('the', 'receiver', 'of'), ('receiver', 'of', 'the'), ('of', 'the', 'message'), ('the', 'message', '('), ('message', '(', 'string'), ('(', 'string', 'format'), ('string', 'format', '.'), ('format', '.', 'russia'), ('.', 'russia', ','), ('russia', ',', 'turkey'), (',', 'turkey', ','), ('turkey', ',', 'england'), (',', 'england', '...'), ('england', '...', ')'), ('...', ')', 'messages'), (')', 'messages', ':'), ('messages', ':', 'the'), (':', 'the', 'raw'), ('the', 'raw', 'message'), ('raw', 'message', 'string'), ('message', 'string', '('), ('string', '(', 'string'), ('(', 'string', 'format'), ('string', 'format', '.'), ('format', '.', 'ranges'), ('.', 'ranges', 'in'), ('ranges', 'in', 'length'), ('in', 'length', 'from'), ('length', 'from', 'one'), ('from', 'one', 'word'), ('one', 'word', 'to'), ('word', 'to', 'paragraphs'), ('to', 'paragraphs', 'in'), ('paragraphs', 'in', 'length'), ('in', 'length', ')'), ('length', ')', 'sender_labels'), (')', 'sender_labels', ':'), ('sender_labels', ':', 'indicates'), (':', 'indicates', 'if'), ('indicates', 'if', 'the'), ('if', 'the', 'sender'), ('the', 'sender', 'of'), ('sender', 'of', 'the'), ('of', 'the', 'message'), ('the', 'message', 'selected'), ('message', 'selected', 'that'), ('selected', 'that', 'the'), ('that', 'the', 'message'), ('the', 'message', 'is'), ('message', 'is', 'truthful'), ('is', 'truthful', ','), ('truthful', ',', 'true'), (',', 'true', ','), ('true', ',', 'or'), (',', 'or', 'deceptive'), ('or', 'deceptive', ','), ('deceptive', ',', 'false'), (',', 'false', '.'), ('false', '.', 'This'), ('.', 'This', 'is'), ('This', 'is', 'used'), ('is', 'used', 'for'), ('used', 'for', 'our'), ('for', 'our', 'ACTUAL_LIE'), ('our', 'ACTUAL_LIE', 'calculation'), ('ACTUAL_LIE', 'calculation', '('), ('calculation', '(', 'true/false'), ('(', 'true/false', 'which'), ('true/false', 'which', 'can'), ('which', 'can', 'be'), ('can', 'be', 'bool'), ('be', 'bool', 'or'), ('bool', 'or', 'string'), ('or', 'string', 'format'), ('string', 'format', ')'), ('format', ')', 'receiver_labels'), (')', 'receiver_labels', ':'), ('receiver_labels', ':', 'indicates'), (':', 'indicates', 'if'), ('indicates', 'if', 'the'), ('if', 'the', 'receiver'), ('the', 'receiver', 'of'), ('receiver', 'of', 'the'), ('of', 'the', 'message'), ('the', 'message', 'selected'), ('message', 'selected', 'that'), ('selected', 'that', 'the'), ('that', 'the', 'message'), ('the', 'message', 'is'), ('message', 'is', 'perceived'), ('is', 'perceived', 'as'), ('perceived', 'as', 'truthful'), ('as', 'truthful', ','), ('truthful', ',', 'true'), (',', 'true', ','), ('true', ',', 'or'), (',', 'or', 'deceptive'), ('or', 'deceptive', ','), ('deceptive', ',', 'false'), (',', 'false', '.'), ('false', '.', 'In'), ('.', 'In', '<'), ('In', '<', '10'), ('<', '10', '%'), ('10', '%', 'of'), ('%', 'of', 'the'), ('of', 'the', 'cases'), ('the', 'cases', ','), ('cases', ',', 'no'), (',', 'no', 'annotation'), ('no', 'annotation', 'was'), ('annotation', 'was', 'received'), ('was', 'received', '.'), ('received', '.', 'This'), ('.', 'This', 'is'), ('This', 'is', 'used'), ('is', 'used', 'for'), ('used', 'for', 'our'), ('for', 'our', 'SUSPECTED_LIE'), ('our', 'SUSPECTED_LIE', 'calculation'), ('SUSPECTED_LIE', 'calculation', '('), ('calculation', '(', 'string'), ('(', 'string', 'format'), ('string', 'format', '.'), ('format', '.', 'true/false/'), ('.', 'true/false/', "''"), ('true/false/', "''", 'NOANNOTATION'), ("''", 'NOANNOTATION', "''"), ('NOANNO ...
#
#  N- grams(4): [('speakers', ':', 'the', 'sender'), (':', 'the', 'sender', 'of'), ('the', 'sender', 'of', 'the'), ('sender', 'of', 'the', 'message'), ('of', 'the', 'message', '('), ('the', 'message', '(', 'string'), ('message', '(', 'string', 'format'), ('(', 'string', 'format', '.'), ('string', 'format', '.', 'russia'), ('format', '.', 'russia', ','), ('.', 'russia', ',', 'turkey'), ('russia', ',', 'turkey', ','), (',', 'turkey', ',', 'england'), ('turkey', ',', 'england', '...'), (',', 'england', '...', ')'), ('england', '...', ')', 'receivers'), ('...', ')', 'receivers', ':'), (')', 'receivers', ':', 'the'), ('receivers', ':', 'the', 'receiver'), (':', 'the', 'receiver', 'of'), ('the', 'receiver', 'of', 'the'), ('receiver', 'of', 'the', 'message'), ('of', 'the', 'message', '('), ('the', 'message', '(', 'string'), ('message', '(', 'string', 'format'), ('(', 'string', 'format', '.'), ('string', 'format', '.', 'russia'), ('format', '.', 'russia', ','), ('.', 'russia', ',', 'turkey'), ('russia', ',', 'turkey', ','), (',', 'turkey', ',', 'england'), ('turkey', ',', 'england', '...'), (',', 'england', '...', ')'), ('england', '...', ')', 'messages'), ('...', ')', 'messages', ':'), (')', 'messages', ':', 'the'), ('messages', ':', 'the', 'raw'), (':', 'the', 'raw', 'message'), ('the', 'raw', 'message', 'string'), ('raw', 'message', 'string', '('), ('message', 'string', '(', 'string'), ('string', '(', 'string', 'format'), ('(', 'string', 'format', '.'), ('string', 'format', '.', 'ranges'), ('format', '.', 'ranges', 'in'), ('.', 'ranges', 'in', 'length'), ('ranges', 'in', 'length', 'from'), ('in', 'length', 'from', 'one'), ('length', 'from', 'one', 'word'), ('from', 'one', 'word', 'to'), ('one', 'word', 'to', 'paragraphs'), ('word', 'to', 'paragraphs', 'in'), ('to', 'paragraphs', 'in', 'length'), ('paragraphs', 'in', 'length', ')'), ('in', 'length', ')', 'sender_labels'), ('length', ')', 'sender_labels', ':'), (')', 'sender_labels', ':', 'indicates'), ('sender_labels', ':', 'indicates', 'if'), (':', 'indicates', 'if', 'the'), ('indicates', 'if', 'the', 'sender'), ('if', 'the', 'sender', 'of'), ('the', 'sender', 'of', 'the'), ('sender', 'of', 'the', 'message'), ('of', 'the', 'message', 'selected'), ('the', 'message', 'selected', 'that'), ('message', 'selected', 'that', 'the'), ('selected', 'that', 'the', 'message'), ('that', 'the', 'message', 'is'), ('the', 'message', 'is', 'truthful'), ('message', 'is', 'truthful', ','), ('is', 'truthful', ',', 'true'), ('truthful', ',', 'true', ','), (',', 'true', ',', 'or'), ('true', ',', 'or', 'deceptive'), (',', 'or', 'deceptive', ','), ('or', 'deceptive', ',', 'false'), ('deceptive', ',', 'false', '.'), (',', 'false', '.', 'This'), ('false', '.', 'This', 'is'), ('.', 'This', 'is', 'used'), ('This', 'is', 'used', 'for'), ('is', 'used', 'for', 'our'), ('used', 'for', 'our', 'ACTUAL_LIE'), ('for', 'our', 'ACTUAL_LIE', 'calculation'), ('our', 'ACTUAL_LIE', 'calculation', '('), ('ACTUAL_LIE', 'calculation', '(', 'true/false'), ('calculation', '(', 'true/false', 'which'), ('(', 'true/false', 'which', 'can'), ('true/false', 'which', 'can', 'be'), ('which', 'can', 'be', 'bool'), ('can', 'be', 'bool', 'or'), ('be', 'bool', 'or', 'string'), ('bool', 'or', 'string', 'format'), ('or', 'string', 'format', ')'), ('string', 'format', ')', 'receiver_labels'), ('format', ')', 'receiver_labels', ':'), (')', 'receiver_labels', ':', 'indicates'), ('receiver_labels', ':', 'indicates', 'if'), (':', 'indicates', 'if', 'the'), ('indicates', 'if', 'the', 'receiver'), ('if', 'the', 'receiver', 'of'), ('the', 'receiver', 'of', 'the'), ('receiver', 'of', 'the', 'message'), ('of', 'the', 'message', 'selected'), ('the', 'message', 'selected', 'that'), ('message', 'selected', 'that', 'the'), ('selected', 'that', 'the', 'message'), ('that', 'the', 'message', 'is'), ('the', 'message', 'is', 'perceived'), ('message', 'is', 'perceived', 'as'), ('is', 'perceived', 'as', 'truthful'), ('perceived', 'as', 'truthful', ','), ('as', 'tru ...
